# %%
import pandas as pd

# %%
data = pd.read_csv('cities.csv',index_col="Unnamed: 0")
html = data.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Baykit</td>
#       <td>61.67</td>
#       <td>96.37</td>
#       <td>21.00</td>
#       <td>94</td>
#       <td>100</td>
#       <td>6.96</td>
#       <td>RU</td>
#       <td>1606064507</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Grindavik</td>
#       <td>63.84</td>
#       <td>-22.43</td>
#       <td>33.80</td>
#       <td>73</td>
#       <td>75</td>
#       <td>5.82</td>
#       <td>IS</td>
#       <td>1606064509</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Bredasdorp</td>
#       <td>-34.53</td>
#       <td>20.04</td>
#       <td>66.20</td>
# ...
